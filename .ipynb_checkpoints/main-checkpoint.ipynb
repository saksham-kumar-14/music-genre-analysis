# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#    song_id keyword_1  keyword_2  keyword_3      genre
# 0       74    guitar      happy  distorted       rock
# 1      103     brass  energetic    melodic  classical
# 2      201     banjo      happy   acoustic    country
# 3      194     synth  energetic      heavy    hip-hop
# 4      184     synth  energetic       slow    hip-hop

# %% [markdown]
# ## Generating word embeddings for the keywords using BoW

# %%
def generate_freq_for_df_keywords(df):

    mapping = {}
    for idx, rows in df.iterrows():
        if rows['keyword_1'] in mapping:
            mapping[rows['keyword_1']] += 1
        else:
            mapping[rows['keyword_1']] = 1

        if rows['keyword_2'] in mapping:
            mapping[rows['keyword_2']] += 1
        else:
            mapping[rows['keyword_2']] = 1

        if rows['keyword_3'] in mapping:
            mapping[rows['keyword_3']] += 1
        else:
            mapping[rows['keyword_3']] = 1

    return mapping

# %%
def generate_vector_for_df_keywords(df):
    freq = generate_freq_for_df_keywords(df)

    ans = []
    for idx, row in df.iterrows():
        arr = []
        arr.append(freq[row['keyword_1']])
        arr.append(freq[row['keyword_2']])
        arr.append(freq[row['keyword_3']])
        ans.append(np.array(arr))

    
    return np.array(ans)

# %%
print(generate_vector_for_df_keywords(df))
# Out:
# [[65 30  5]
#  [11 27 27]
#  [ 6 30  9]
#  [43 27 10]
#  [43 27 23]
#  [11 11 24]
#  [65 27 27]
#  [65 30 10]
#  [10 28 27]
#  [65 27 27]
#  [12 11 14]
#  [10 11 23]
#  [65  3  6]
#  [11 30 23]
#  [65 30 24]
#  [65 28 24]
#  [11 28 28]
#  [65 11 14]
#  [65 30 24]
#  [43 12 23]
#  [65 27  6]
#  [65 21  9]
#  [43 30 28]
#  [43 27 24]
#  [65 24 28]
#  [65 12 10]
#  [65 30 27]
#  [65 27 28]
#  [43 27 28]
#  [65 27  9]
#  [65 27  5]
#  [65 28 24]
#  [12 21 23]
#  [10 28 24]
#  [10 11 28]
#  [65 12  5]
#  [43 30 14]
#  [ 6 11  6]
#  [43 28 28]
#  [65 24 14]
#  [65 28 27]
#  [12 28 27]
#  [43 21 14]
#  [65  3 23]
#  [10 27 23]
#  [65 28 10]
#  [ 6 11 28]
#  [43 27 23]
#  [65 21  9]
#  [65 12 28]
#  [11 27 23]
#  [11 30 28]
#  [65 27 10]
#  [43 21 24]
#  [65 28 27]
#  [65 30  6]
#  [43 21 28]
#  [43 28 28]
#  [43 11 28]
#  [ 6 28  6]
#  [65 30 28]
#  [65 21 10]
#  [43 12 14]
#  [65 27 28]
#  [43 28 10]
#  [43 11 27]
#  [43 27 27]
#  [65 21  6]
#  [65 28  5]
#  [12 11 24]
#  [65 21 27]
# ...

# %% [markdown]
# ## Dimensionality Reduction

# %%
# reducing features to useful features only
